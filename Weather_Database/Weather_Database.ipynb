# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | goundi
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | shestakovo
# Processing Record 5 of Set 1 | mandalgovi
# Processing Record 6 of Set 1 | campana
# Processing Record 7 of Set 1 | fairbanks
# Processing Record 8 of Set 1 | maragogi
# Processing Record 9 of Set 1 | kavieng
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | hambantota
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | kathu
# Processing Record 20 of Set 1 | saldanha
# Processing Record 21 of Set 1 | zhigansk
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | denpasar
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | coihaique
# Processing Record 35 of Set 1 | bagdarin
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | seoul
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 1 | akhisar
# Processing Record 41 of Set 1 | shetpe
# Processing Record 42 of Set 1 | digby
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | batagay-alyta
# Processing Record 45 of Set 1 | pedasi
# Processing Record 46 of Set 1 | buchanan
# Processing Record 47 of Set 1 | salalah
# Processing Record 48 of Set 1 | egvekinot
# Processing Record 49 of Set 1 | sabang
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | cap-chat
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | eyl
# Processing Record 6 of Set 2 | pacific grove
# Processing Record 7 of Set 2 | garowe
# Processing Record 8 of Set 2 | san vicente
# Processing Record 9 of Set 2 | wajima
# Processing Record 10 of Set 2 | palmer
# Processing Record 11 of Set 2 | college
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | micheweni
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | mikhaylovka
# Processing Record 19 of Set 2 | semey
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | calvinia
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | hervey bay
# Processing Record 33 of Set 2 | isangel
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | xining
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | srandakan
# Processing Record 38 of Set 2 | treinta y tres
# Processing Record 39 of Set 2 | kaitangata
# Processing Record 40 of Set 2 | okha
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | safford
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | cap malheureux
# Processing Record 46 of Set 2 | tutoia
# Processing Record 47 of Set 2 | tessalit
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | vilyuysk
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | blackwater
# Processing Record 2 of Set 3 | mizque
# Processing Record 3 of Set 3 | portland
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | shelekhov
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | corona
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | chicama
# Processing Record 17 of Set 3 | makakilo city
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 3 | obregon
# Processing Record 21 of Set 3 | bonavista
# Processing Record 22 of Set 3 | san quintin
# Processing Record 23 of Set 3 | riyadh
# Processing Record 24 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 25 of Set 3 | oshawa
# Processing Record 26 of Set 3 | shar
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | mendi
# Processing Record 29 of Set 3 | baie-comeau
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | grand gaube
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | sioux lookout
# Processing Record 34 of Set 3 | henties bay
# Processing Record 35 of Set 3 | pundaguitan
# Processing Record 36 of Set 3 | jining
# Processing Record 37 of Set 3 | ukiah
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | corumba
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | kikwit
# Processing Record 42 of Set 3 | seddon
# Processing Record 43 of Set 3 | nehe
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | kabinda
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | stupino
# Processing Record 48 of Set 3 | dzhebariki-khaya
# Processing Record 49 of Set 3 | hobyo
# Processing Record 50 of Set 3 | christchurch
# Processing Record 1 of Set 4 | puerto ayora
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | camopi
# Processing Record 4 of Set 4 | cravo norte
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | mlonggo
# Processing Record 7 of Set 4 | aklavik
# Processing Record 8 of Set 4 | mantua
# Processing Record 9 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | kunya
# Processing Record 12 of Set 4 | aguada de pasajeros
# Processing Record 13 of Set 4 | kushiro
# Processing Record 14 of Set 4 | dikson
# Processing Record 15 of Set 4 | tianmen
# Processing Record 16 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | porto torres
# Processing Record 21 of Set 4 | labytnangi
# Processing Record 22 of Set 4 | puerto escondido
# Processing Record 23 of Set 4 | elat
# Processing Record 24 of Set 4 | abu dhabi
# Processing Record 25 of Set 4 | wanaka
# Processing Record 26 of Set 4 | klaksvik
# Processing Record 27 of Set 4 | bayji
# Processing Record 28 of Set 4 | beauvais
# Processing Record 29 of Set 4 | nivala
# Processing Record 30 of Set 4 | cockburn town
# Processing Record 31 of Set 4 | shizunai
# Processing Record 32 of Set 4 | manaus
# Processing Record 33 of Set 4 | fernley
# Processing Record 34 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 4 | vostok
# Processing Record 36 of Set 4 | abaete
# Processing Record 37 of Set 4 | jalu
# Processing Record 38 of Set 4 | ucluelet
# Processing Record 39 of Set 4 | sassandra
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | samarai
# Processing Record 43 of Set 4 | guelengdeng
# City not found. Skipping...
# Processing Record 44 of Set 4 | khatanga
# Processing Record 45 of Set 4 | mastic beach
# Processing Record 46 of Set 4 | broome
# Processing Record 47 of Set 4 | biloela
# Processing Record 48 of Set 4 | meyrin
# Processing Record 49 of Set 4 | pevek
# Processing Record 50 of Set 4 | luderitz
# Processing Record 1 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 5 | butte
# Processing Record 3 of Set 5 | shenjiamen
# Processing Record 4 of Set 5 | khudumelapye
# Processing Record 5 of Set 5 | leningradskiy
# Processing Record 6 of Set 5 | karratha
# Processing Record 7 of Set 5 | yumen
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | do gonbadan
# Processing Record 10 of Set 5 | poso
# Processing Record 11 of Set 5 | nouadhibou
# Processing Record 12 of Set 5 | ancud
# Processing Record 13 of Set 5 | port-gentil
# Processing Record 14 of Set 5 | ovre ardal
# Processing Record 15 of Set 5 | maldonado
# Processing Record 16 of Set 5 | ayan
# Processing Record 17 of Set 5 | bandundu
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | namatanai
# Processing Record 20 of Set 5 | santa cruz
# Processing Record 21 of Set 5 | kristiansund
# Processing Record 22 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 5 | kruisfontein
# Processing Record 24 of Set 5 | cururupu
# Processing Record 25 of Set 5 | vila franca do campo
# Processing Record 26 of Set 5 | kamenka
# Processing Record 27 of Set 5 | ippy
# Processing Record 28 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 5 | srednekolymsk
# Processing Record 30 of Set 5 | pali
# Processing Record 31 of Set 5 | lapeer
# Processing Record 32 of Set 5 | novoagansk
# Processing Record 33 of Set 5 | black river
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | visnes
# Processing Record 36 of Set 5 | sonoita
# Processing Record 37 of Set 5 | touros
# Processing Record 38 of Set 5 | vanimo
# Processing Record 39 of Set 5 | meadow lake
# Processing Record 40 of Set 5 | ishigaki
# Processing Record 41 of Set 5 | sawtell
# Processing Record 42 of Set 5 | matara
# Processing Record 43 of Set 5 | miles city
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 5 | sal rei
# Processing Record 47 of Set 5 | sao joao dos patos
# Processing Record 48 of Set 5 | tuatapere
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | barra do garcas
# Processing Record 1 of Set 6 | codrington
# Processing Record 2 of Set 6 | nizwa
# Processing Record 3 of Set 6 | marawi
# Processing Record 4 of Set 6 | inhambane
# Processing Record 5 of Set 6 | jodhpur
# Processing Record 6 of Set 6 | wajir
# Processing Record 7 of Set 6 | zhigalovo
# Processing Record 8 of Set 6 | coripata
# Processing Record 9 of Set 6 | polunochnoye
# Processing Record 10 of Set 6 | farah
# Processing Record 11 of Set 6 | kiunga
# Processing Record 12 of Set 6 | maltahohe
# Processing Record 13 of Set 6 | santa vitoria do palmar
# Processing Record 14 of Set 6 | itamarandiba
# Processing Record 15 of Set 6 | najran
# Processing Record 16 of Set 6 | crotone
# Processing Record 17 of Set 6 | angra
# City not found. Skipping...
# Processing Record 18 of Set 6 | cidreira
# Processing Record 19 of Set 6 | parana
# Processing Record 20 of Set 6 | doha
# Processing Record 21 of Set 6 | korla
# Processing Record 22 of Set 6 | fortuna
# Processing Record 23 of Set 6 | batticaloa
# Processing Record 24 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 6 | baracoa
# Processing Record 26 of Set 6 | chiesanuova
# Processing Record 27 of Set 6 | arlit
# Processing Record 28 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 6 | charlestown
# Processing Record 30 of Set 6 | yen bai
# Processing Record 31 of Set 6 | asfi
# Processing Record 32 of Set 6 | loubomo
# Processing Record 33 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 6 | mercedes
# Processing Record 35 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 6 | chapada dos guimaraes
# Processing Record 37 of Set 6 | misratah
# Processing Record 38 of Set 6 | pizhma
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 41 of Set 6 | swan hill
# Processing Record 42 of Set 6 | methoni
# Processing Record 43 of Set 6 | anori
# Processing Record 44 of Set 6 | ambanja
# Processing Record 45 of Set 6 | ponta delgada
# Processing Record 46 of Set 6 | alpena
# Processing Record 47 of Set 6 | tilichiki
# Processing Record 48 of Set 6 | araouane
# Processing Record 49 of Set 6 | naryan-mar
# Processing Record 50 of Set 6 | oxford
# Processing Record 1 of Set 7 | noumea
# Processing Record 2 of Set 7 | road town
# Processing Record 3 of Set 7 | husavik
# Processing Record 4 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 7 | yaring
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | leshukonskoye
# Processing Record 8 of Set 7 | waipawa
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | cabo san lucas
# Processing Record 11 of Set 7 | turan
# Processing Record 12 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 13 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 7 | hofn
# Processing Record 15 of Set 7 | karachi
# Processing Record 16 of Set 7 | walvis bay
# Processing Record 17 of Set 7 | hithadhoo
# Processing Record 18 of Set 7 | miracema do tocantins
# Processing Record 19 of Set 7 | nantucket
# Processing Record 20 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 21 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | celestun
# Processing Record 24 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | mazagao
# Processing Record 28 of Set 7 | pimentel
# Processing Record 29 of Set 7 | urusha
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | acapulco
# Processing Record 32 of Set 7 | moron
# Processing Record 33 of Set 7 | chuy
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | rajgurunagar
# Processing Record 36 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | ribeira grande
# Processing Record 39 of Set 7 | katsuura
# Processing Record 40 of Set 7 | prince albert
# Processing Record 41 of Set 7 | neyshabur
# Processing Record 42 of Set 7 | abeche
# Processing Record 43 of Set 7 | jasper
# Processing Record 44 of Set 7 | talnakh
# Processing Record 45 of Set 7 | toamasina
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | thompson
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | kongolo
# Processing Record 50 of Set 7 | roblin
# Processing Record 1 of Set 8 | limbang
# Processing Record 2 of Set 8 | pangai
# Processing Record 3 of Set 8 | vallenar
# Processing Record 4 of Set 8 | nadym
# Processing Record 5 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 8 | severo-kurilsk
# Processing Record 7 of Set 8 | pandua
# Processing Record 8 of Set 8 | coquimbo
# Processing Record 9 of Set 8 | jiexiu
# Processing Record 10 of Set 8 | charcas
# Processing Record 11 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 12 of Set 8 | puerto del rosario
# Processing Record 13 of Set 8 | cradock
# Processing Record 14 of Set 8 | vao
# Processing Record 15 of Set 8 | pitimbu
# Processing Record 16 of Set 8 | cacoal
# Processing Record 17 of Set 8 | gillette
# Processing Record 18 of Set 8 | horsham
# Processing Record 19 of Set 8 | anloga
# Processing Record 20 of Set 8 | port hardy
# Processing Record 21 of Set 8 | saint-germain-de-grantham
# Processing Record 22 of Set 8 | nelson bay
# Processing Record 23 of Set 8 | illapel
# Processing Record 24 of Set 8 | kamaishi
# Processing Record 25 of Set 8 | dudinka
# Processing Record 26 of Set 8 | agadez
# Processing Record 27 of Set 8 | wanning
# Processing Record 28 of Set 8 | gorontalo
# Processing Record 29 of Set 8 | port macquarie
# Processing Record 30 of Set 8 | homer
# Processing Record 31 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 8 | port blair
# Processing Record 33 of Set 8 | ahuimanu
# Processing Record 34 of Set 8 | jiaozuo
# Processing Record 35 of Set 8 | port hawkesbury
# Processing Record 36 of Set 8 | puerto salgar
# Processing Record 37 of Set 8 | awjilah
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | port hedland
# Processing Record 40 of Set 8 | gondanglegi
# Processing Record 41 of Set 8 | narsaq
# Processing Record 42 of Set 8 | kemijarvi
# Processing Record 43 of Set 8 | richards bay
# Processing Record 44 of Set 8 | flin flon
# Processing Record 45 of Set 8 | ikalamavony
# Processing Record 46 of Set 8 | verkhnyaya toyma
# Processing Record 47 of Set 8 | vizinga
# Processing Record 48 of Set 8 | georgetown
# Processing Record 49 of Set 8 | jeremoabo
# Processing Record 50 of Set 8 | rocha
# Processing Record 1 of Set 9 | prince rupert
# Processing Record 2 of Set 9 | fare
# Processing Record 3 of Set 9 | eureka
# Processing Record 4 of Set 9 | outram
# Processing Record 5 of Set 9 | aksarka
# Processing Record 6 of Set 9 | gazanjyk
# Processing Record 7 of Set 9 | sun city west
# Processing Record 8 of Set 9 | urumqi
# Processing Record 9 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 9 | salta
# Processing Record 11 of Set 9 | phuket
# Processing Record 12 of Set 9 | sao miguel do araguaia
# Processing Record 13 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 9 | maniitsoq
# Processing Record 15 of Set 9 | miranda
# Processing Record 16 of Set 9 | sainte-martine
# Processing Record 17 of Set 9 | chapleau
# Processing Record 18 of Set 9 | lucapa
# Processing Record 19 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 9 | lagoa
# Processing Record 21 of Set 9 | hauge
# Processing Record 22 of Set 9 | otradnoye
# Processing Record 23 of Set 9 | rosario oeste
# Processing Record 24 of Set 9 | trinidad
# Processing Record 25 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 9 | steinbach
# Processing Record 27 of Set 9 | ahlat
# Processing Record 28 of Set 9 | haines junction
# Processing Record 29 of Set 9 | ajaccio
# Processing Record 30 of Set 9 | sa kaeo
# Processing Record 31 of Set 9 | ostrovnoy
# Processing Record 32 of Set 9 | mandali
# Processing Record 33 of Set 9 | bengkulu
# Processing Record 34 of Set 9 | russell
# Processing Record 35 of Set 9 | bolshaya atnya
# City not found. Skipping...
# Processing Record 36 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 37 of Set 9 | qui nhon
# Processing Record 38 of Set 9 | bonnyville
# Processing Record 39 of Set 9 | mitsamiouli
# Processing Record 40 of Set 9 | magistralnyy
# Processing Record 41 of Set 9 | tvoroyri
# Processing Record 42 of Set 9 | valdivia
# Processing Record 43 of Set 9 | amiens
# Processing Record 44 of Set 9 | basoko
# Processing Record 45 of Set 9 | lima
# Processing Record 46 of Set 9 | omsukchan
# Processing Record 47 of Set 9 | okhotsk
# Processing Record 48 of Set 9 | hurghada
# Processing Record 49 of Set 9 | gizo
# Processing Record 50 of Set 9 | mehamn
# Processing Record 1 of Set 10 | orange
# Processing Record 2 of Set 10 | villa rica
# Processing Record 3 of Set 10 | ola
# Processing Record 4 of Set 10 | zhuhai
# Processing Record 5 of Set 10 | faanui
# Processing Record 6 of Set 10 | bataipora
# Processing Record 7 of Set 10 | kirkland lake
# Processing Record 8 of Set 10 | olavarria
# Processing Record 9 of Set 10 | roma
# Processing Record 10 of Set 10 | todos santos
# Processing Record 11 of Set 10 | parkersburg
# Processing Record 12 of Set 10 | el alto
# Processing Record 13 of Set 10 | pangnirtung
# Processing Record 14 of Set 10 | semnan
# Processing Record 15 of Set 10 | riohacha
# Processing Record 16 of Set 10 | varhaug
# Processing Record 17 of Set 10 | kabompo
# Processing Record 18 of Set 10 | xunchang
# Processing Record 19 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 10 | sergeyevka
# Processing Record 21 of Set 10 | fort-shevchenko
# Processing Record 22 of Set 10 | hoima
# Processing Record 23 of Set 10 | melur
# Processing Record 24 of Set 10 | marzuq
# Processing Record 25 of Set 10 | mo i rana
# Processing Record 26 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 10 | malatya
# Processing Record 28 of Set 10 | tsiroanomandidy
# Processing Record 29 of Set 10 | kenai
# Processing Record 30 of Set 10 | kholodnyy
# Processing Record 31 of Set 10 | lata
# Processing Record 32 of Set 10 | tairua
# Processing Record 33 of Set 10 | ouesso
# Processing Record 34 of Set 10 | yantal
# Processing Record 35 of Set 10 | odweyne
# Processing Record 36 of Set 10 | xingyi
# Processing Record 37 of Set 10 | kochi
# Processing Record 38 of Set 10 | malibu
# Processing Record 39 of Set 10 | mamakan
# Processing Record 40 of Set 10 | tirlyanskiy
# Processing Record 41 of Set 10 | mangaratiba
# Processing Record 42 of Set 10 | isperih
# Processing Record 43 of Set 10 | safranbolu
# Processing Record 44 of Set 10 | aswan
# Processing Record 45 of Set 10 | wattegama
# Processing Record 46 of Set 10 | jertih
# Processing Record 47 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 10 | nikki
# Processing Record 49 of Set 10 | gemena
# Processing Record 50 of Set 10 | ulladulla
# Processing Record 1 of Set 11 | banyuwangi
# Processing Record 2 of Set 11 | hit
# Processing Record 3 of Set 11 | kangaatsiaq
# Processing Record 4 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 5 of Set 11 | diamantino
# Processing Record 6 of Set 11 | bereda
# Processing Record 7 of Set 11 | binga
# Processing Record 8 of Set 11 | kamwenge
# Processing Record 9 of Set 11 | sao joao da barra
# Processing Record 10 of Set 11 | tambura
# Processing Record 11 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 11 | shimoda
# Processing Record 14 of Set 11 | guider
# Processing Record 15 of Set 11 | krasnoselkup
# Processing Record 16 of Set 11 | requena
# Processing Record 17 of Set 11 | batagay
# Processing Record 18 of Set 11 | opuwo
# Processing Record 19 of Set 11 | akyab
# Processing Record 20 of Set 11 | port shepstone
# Processing Record 21 of Set 11 | cabul-an
# Processing Record 22 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 11 | nome
# Processing Record 24 of Set 11 | quatre cocos
# Processing Record 25 of Set 11 | ryotsu
# Processing Record 26 of Set 11 | ruwi
# Processing Record 27 of Set 11 | la libertad
# Processing Record 28 of Set 11 | salinopolis
# Processing Record 29 of Set 11 | tanout
# Processing Record 30 of Set 11 | hualmay
# Processing Record 31 of Set 11 | nueva loja
# Processing Record 32 of Set 11 | idritsa
# Processing Record 33 of Set 11 | olinda
# Processing Record 34 of Set 11 | takoradi
# Processing Record 35 of Set 11 | catalao
# Processing Record 36 of Set 11 | savannah bight
# Processing Record 37 of Set 11 | sobolevo
# Processing Record 38 of Set 11 | lexington
# Processing Record 39 of Set 11 | sinnamary
# Processing Record 40 of Set 11 | gravdal
# Processing Record 41 of Set 11 | nichinan
# Processing Record 42 of Set 11 | sechura
# Processing Record 43 of Set 11 | cortes
# Processing Record 44 of Set 11 | jaramana
# City not found. Skipping...
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | praia da vitoria
# Processing Record 47 of Set 11 | boueni
# Processing Record 48 of Set 11 | mana
# Processing Record 49 of Set 11 | maraa
# Processing Record 50 of Set 11 | ondjiva
# Processing Record 1 of Set 12 | palmas
# Processing Record 2 of Set 12 | ciudad bolivar
# Processing Record 3 of Set 12 | asau
# Processing Record 4 of Set 12 | carayao
# Processing Record 5 of Set 12 | sola
# Processing Record 6 of Set 12 | khani
# Processing Record 7 of Set 12 | fort nelson
# Processing Record 8 of Set 12 | oriximina
# Processing Record 9 of Set 12 | usak
# Processing Record 10 of Set 12 | auki
# Processing Record 11 of Set 12 | taoudenni
# Processing Record 12 of Set 12 | kasongo-lunda
# Processing Record 13 of Set 12 | kosh-agach
# Processing Record 14 of Set 12 | sibolga
# Processing Record 15 of Set 12 | benjamin constant
# Processing Record 16 of Set 12 | yunyang
# Processing Record 17 of Set 12 | atar
# Processing Record 18 of Set 12 | camana
# Processing Record 19 of Set 12 | olga
# Processing Record 20 of Set 12 | yulara
# Processing Record 21 of Set 12 | kiama
# Processing Record 22 of Set 12 | kudahuvadhoo
# Processing Record 23 of Set 12 | snezhnogorsk
# Processing Record 24 of Set 12 | kashmor
# Processing Record 25 of Set 12 | khandyga
# Processing Record 26 of Set 12 | kahului
# Processing Record 27 of Set 12 | codajas
# Processing Record 28 of Set 12 | gamba
# Processing Record 29 of Set 12 | bella union
# Processing Record 30 of Set 12 | nur
# Processing Record 31 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 32 of Set 12 | verkhnevilyuysk
# Processing Record 33 of Set 12 | dakar
# Processing Record 34 of Set 12 | naze
# Processing Record 35 of Set 12 | mandera
# Processing Record 36 of Set 12 | brae
# Processing Record 37 of Set 12 | bambanglipuro
# Processing Record 38 of Set 12 | sovetskiy
# Processing Record 39 of Set 12 | kidal
# Processing Record 40 of Set 12 | andros town
# Processing Record 41 of Set 12 | panjab
# Processing Record 42 of Set 12 | qingdao
# Processing Record 43 of Set 12 | lahaina
# Processing Record 44 of Set 12 | rudkobing
# Processing Record 45 of Set 12 | puerto leguizamo
# Processing Record 46 of Set 12 | hirado
# Processing Record 47 of Set 12 | gazojak
# Processing Record 48 of Set 12 | labuhan
# Processing Record 49 of Set 12 | nishihara
# Processing Record 50 of Set 12 | williams lake
# Processing Record 1 of Set 13 | ballina
# Processing Record 2 of Set 13 | raudeberg
# Processing Record 3 of Set 13 | nyurba
# Processing Record 4 of Set 13 | gualeguaychu
# Processing Record 5 of Set 13 | chateaubelair
# Processing Record 6 of Set 13 | malanje
# Processing Record 7 of Set 13 | baboua
# City not found. Skipping...
# Processing Record 8 of Set 13 | benjamin hill
# Processing Record 9 of Set 13 | kaka
# Processing Record 10 of Set 13 | itaituba
# Processing Record 11 of Set 13 | cayenne
# Processing Record 12 of Set 13 | bukachacha
# Processing Record 13 of Set 13 | uglich
# Processing Record 14 of Set 13 | tongchuan
# Processing Record 15 of Set 13 | victor harbor
# Processing Record 16 of Set 13 | tukan
# Processing Record 17 of Set 13 | chapais
# Processing Record 18 of Set 13 | balkanabat
# Processing Record 19 of Set 13 | umm lajj
# Processing Record 20 of Set 13 | ternate
# Processing Record 21 of Set 13 | cache creek
# Processing Record 22 of Set 13 | hokitika
# Processing Record 23 of Set 13 | santa fe
# Processing Record 24 of Set 13 | kannur
# Processing Record 25 of Set 13 | komsomolskiy
# Processing Record 26 of Set 13 | caravelas
# Processing Record 27 of Set 13 | ankazoabo
# Processing Record 28 of Set 13 | burica
# City not found. Skipping...
# Processing Record 29 of Set 13 | bilibino
# Processing Record 30 of Set 13 | augusto correa
# Processing Record 31 of Set 13 | necochea
# Processing Record 32 of Set 13 | lososina
# Processing Record 33 of Set 13 | kibara
# Processing Record 34 of Set 13 | kalnciems
# Processing Record 35 of Set 13 | raton
# Processing Record 36 of Set 13 | shelburne
# Processing Record 37 of Set 13 | churapcha
# Processing Record 38 of Set 13 | ginda
# Processing Record 39 of Set 13 | rostaq
# City not found. Skipping...
# Processing Record 40 of Set 13 | anadyr
# Processing Record 41 of Set 13 | birin
# Processing Record 42 of Set 13 | havre-saint-pierre
# Processing Record 43 of Set 13 | traralgon
# Processing Record 44 of Set 13 | ornskoldsvik
# Processing Record 45 of Set 13 | praya
# Processing Record 46 of Set 13 | la orilla
# Processing Record 47 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 13 | deputatskiy
# Processing Record 49 of Set 13 | birao
# Processing Record 50 of Set 13 | sampit
# Processing Record 1 of Set 14 | dunedin
# Processing Record 2 of Set 14 | inta
# Processing Record 3 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 4 of Set 14 | skjervoy
# Processing Record 5 of Set 14 | hargeysa
# Processing Record 6 of Set 14 | talas
# Processing Record 7 of Set 14 | brawley
# Processing Record 8 of Set 14 | kismayo
# Processing Record 9 of Set 14 | champerico
# Processing Record 10 of Set 14 | piacabucu
# Processing Record 11 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 12 of Set 14 | forssa
# Processing Record 13 of Set 14 | gua musang
# Processing Record 14 of Set 14 | genhe
# Processing Record 15 of Set 14 | kayerkan
# Processing Record 16 of Set 14 | manama
# Processing Record 17 of Set 14 | nkhotakota
# Processing Record 18 of Set 14 | kousseri
# Processing Record 19 of Set 14 | singapore
# Processing Record 20 of Set 14 | krasnouralsk
# Processing Record 21 of Set 14 | burkburnett
# Processing Record 22 of Set 14 | basco
# Processing Record 23 of Set 14 | conde
# Processing Record 24 of Set 14 | zverinogolovskoye
# Processing Record 25 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 26 of Set 14 | la cruz
# Processing Record 27 of Set 14 | manzhouli
# Processing Record 28 of Set 14 | ruteng
# Processing Record 29 of Set 14 | isabela
# Processing Record 30 of Set 14 | bondoukou
# Processing Record 31 of Set 14 | ibra
# Processing Record 32 of Set 14 | newton
# Processing Record 33 of Set 14 | bagua grande
# Processing Record 34 of Set 14 | kembe
# Processing Record 35 of Set 14 | turukhansk
# Processing Record 36 of Set 14 | pemangkat
# Processing Record 37 of Set 14 | vestmannaeyjar
# Processing Record 38 of Set 14 | itoman
# Processing Record 39 of Set 14 | miquelon
# Processing Record 40 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 14 | mundo nuevo
# Processing Record 42 of Set 14 | lake city
# Processing Record 43 of Set 14 | bagabag
# Processing Record 44 of Set 14 | ozieri
# Processing Record 45 of Set 14 | novikovo
# Processing Record 46 of Set 14 | mawlaik
# Processing Record 47 of Set 14 | suntar
# Processing Record 48 of Set 14 | namibe
# Processing Record 49 of Set 14 | shimanovsk
# Processing Record 50 of Set 14 | wagar
# Processing Record 1 of Set 15 | beloha
# Processing Record 2 of Set 15 | laem sing
# Processing Record 3 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 15 | haukipudas
# Processing Record 5 of Set 15 | remerschen
# Processing Record 6 of Set 15 | amapa
# Processing Record 7 of Set 15 | ebebiyin
# Processing Record 8 of Set 15 | gilgit
# Processing Record 9 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 15 | lewiston
# Processing Record 11 of Set 15 | bubaque
# Processing Record 12 of Set 15 | novobirilyussy
# Processing Record 13 of Set 15 | adrar
# Processing Record 14 of Set 15 | tigil
# Processing Record 15 of Set 15 | los llanos de aridane
# Processing Record 16 of Set 15 | tabou
# Processing Record 17 of Set 15 | ati
# Processing Record 18 of Set 15 | aykhal
# Processing Record 19 of Set 15 | preobrazheniye
# Processing Record 20 of Set 15 | batemans bay
# Processing Record 21 of Set 15 | ko samui
# Processing Record 22 of Set 15 | margate
# Processing Record 23 of Set 15 | tahe
# Processing Record 24 of Set 15 | stokmarknes
# Processing Record 25 of Set 15 | lodja
# Processing Record 26 of Set 15 | hoquiam
# Processing Record 27 of Set 15 | tucumcari
# Processing Record 28 of Set 15 | san policarpo
# Processing Record 29 of Set 15 | telfs
# Processing Record 30 of Set 15 | matagami
# Processing Record 31 of Set 15 | jibuti
# Processing Record 32 of Set 15 | vila velha
# Processing Record 33 of Set 15 | kununurra
# Processing Record 34 of Set 15 | pasinler
# Processing Record 35 of Set 15 | registro
# Processing Record 36 of Set 15 | ballangen
# Processing Record 37 of Set 15 | lasa
# Processing Record 38 of Set 15 | yorkton
# Processing Record 39 of Set 15 | laguna
# Processing Record 40 of Set 15 | tiznit
# Processing Record 41 of Set 15 | qaqortoq
# Processing Record 42 of Set 15 | rincon
# Processing Record 43 of Set 15 | goundam
# Processing Record 44 of Set 15 | kapit
# Processing Record 45 of Set 15 | am timan
# Processing Record 46 of Set 15 | te anau
# Processing Record 47 of Set 15 | corinto
# Processing Record 48 of Set 15 | antipovka
# Processing Record 49 of Set 15 | channel-port aux basques
# Processing Record 50 of Set 15 | duluth
# Processing Record 1 of Set 16 | bundaberg
# Processing Record 2 of Set 16 | aljezur
# Processing Record 3 of Set 16 | bilma
# Processing Record 4 of Set 16 | kokopo
# Processing Record 5 of Set 16 | saint anthony
# Processing Record 6 of Set 16 | padang
# Processing Record 7 of Set 16 | dire dawa
# Processing Record 8 of Set 16 | finnsnes
# Processing Record 9 of Set 16 | bay roberts
# Processing Record 10 of Set 16 | stornoway
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_city_df = pd.DataFrame(city_data)
new_city_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Atuona  -9.8000 -139.0333     78.35        76           3       15.95
# 1      Goundi   9.3627   17.3660     70.57        21          99        6.15
# 2  Shestakovo  56.4915  103.9600     -0.60        95          97        2.95
# 3  Mandalgovi  45.7625  106.2708      3.85        68           0        5.06
# 4     Campana -34.1687  -58.9591     78.66        96          98        3.71
# 5   Fairbanks  64.8378 -147.7164     15.76        73           0        0.00
# 6    Maragogi  -9.0122  -35.2225     78.76        79          77        8.88
# 7     Kavieng  -2.5744  150.7967     83.88        75          89        8.25
# 8  Nikolskoye  59.7035   30.7861     17.49       100          81        2.84
# 9        Lebu -37.6167  -73.6500     57.51        89           1       15.01
#
#   Country Current Description                 Date
# 0      PF           clear sky  2022-01-26 03:12:22
# 1      TD     overcast clouds  2022-01-26 03:12:22
# 2      RU     overcast clouds  2022-01-26 03:12:23
# 3      MN           clear sky  2022-01-26 03:12:23
# 4      AR          light rain  2022-01-26 03:12:23
# 5      US           clear sky  2022-01-26 03:11:59
# 6      BR       broken clouds  2022-01-26 03:12:24
# 7      PG          light rain  2022-01-26 03:12:24
# 8      RU       broken clouds  2022-01-26 03:12:24
# 9      CL           clear sky  2022-01-26 03:12:25

# %%
# Reorder columns in DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

new_city_df = new_city_df[new_column_order]
new_city_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Atuona      PF  -9.8000 -139.0333     78.35        76           3
# 1      Goundi      TD   9.3627   17.3660     70.57        21          99
# 2  Shestakovo      RU  56.4915  103.9600     -0.60        95          97
# 3  Mandalgovi      MN  45.7625  106.2708      3.85        68           0
# 4     Campana      AR -34.1687  -58.9591     78.66        96          98
#
#    Wind Speed Current Description
# 0       15.95           clear sky
# 1        6.15     overcast clouds
# 2        2.95     overcast clouds
# 3        5.06           clear sky
# 4        3.71          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_df.to_csv(output_data_file, index_label="City_ID")
